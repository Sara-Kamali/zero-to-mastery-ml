# %%
import pandas as pd

# %%
# There are two main data types
#Creating 1-D data with Series:
series=pd.Series(['BMW','Toyota','Mercedes'])

# %%
print(series)
# Out:
# 0         BMW
# 1      Toyota
# 2    Mercedes
# dtype: object

# %%
series
# Out:
# 0         BMW
# 1      Toyota
# 2    Mercedes
# dtype: object

# %%
colors=pd.Series(['Blue','Red','White'])
colors
# Out:
# 0     Blue
# 1      Red
# 2    White
# dtype: object

# %%
#creating a 2-D data with DataFrame. Pay attention to {} instead of []
car_data=pd.DataFrame({'Car_made':series,'Car_color': colors})
car_data
# Out:
#    Car_made Car_color
# 0       BMW      Blue
# 1    Toyota       Red
# 2  Mercedes     White

# %%
car_sales=pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv('exported_car_sales.csv',index=False)

# %%
exported_car_sales=pd.read_csv('exported_car_sales.csv')
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# /var/folders/y8/49453_6s2pg5_9h0p22bvm5w0000gn/T/ipykernel_28188/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales['Doors'].std()
# Out:
# 0.4714045207910317

# %%
car_prices=pd.Series([15000, 6000, 2800])
car_prices.mean()
# Out:
# 7933.333333333333

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# **Viewing and selecting data**

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
animals=pd.Series(['cat','dog','bird','panda','kuala'],index=[3, 1, 3, 5, 0])
animals
# Out:
# 3      cat
# 1      dog
# 3     bird
# 5    panda
# 0    kuala
# dtype: object

# %%
# loc referes to index
animals.loc[3]
# Out:
# 3     cat
# 3    bird
# dtype: object

# %%
# iloc referes to position
animals.iloc[3]
# Out:
# 'panda'

# %%
#gives data upto position 3
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
# gives data upto and inclusding the position 3
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.head(4)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales['Doors'],car_sales['Make'])
# Out:
# Make   BMW  Honda  Nissan  Toyota
# Doors
# 3        0      0       0       1
# 4        0      3       2       3
# 5        1      0       0       0

# %%
car_sales.groupby(["Colour"]).mean()
# Out:
#         Odometer (KM)     Doors
# Colour
# Black    11179.000000  5.000000
# Blue     44328.333333  3.666667
# Green    99213.000000  4.000000
# Red      87899.000000  4.000000
# White   113684.500000  4.000000

# %%
car_sales['Doors'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Manipulating data

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.00]','').astype(int)
# Out:
# /var/folders/y8/49453_6s2pg5_9h0p22bvm5w0000gn/T/ipykernel_28188/969794088.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.00]','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4      4
# 1   Honda    Red          87899      4      5
# 2  Toyota   Blue          32549      3      7
# 3     BMW  Black          11179      5     22
# 4  Nissan  White         213095      4     35
# 5  Toyota  Green          99213      4     45
# 6   Honda   Blue          45698      4     75
# 7   Honda   Blue          54738      4      7
# 8  Toyota  White          60000      4    625
# 9  Nissan  White          31600      4     97

# %%
car_sales['Price'].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales_missing=pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# # inplace=True to replace the old value with the new one

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(),inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing=pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing_dropped=car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv('car_sales_missing_dropped.csv')

# %%
seats_column=pd.Series([5,6,5,4,5])
car_sales['Seats']=seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4      4    5.0
# 1   Honda    Red          87899      4      5    6.0
# 2  Toyota   Blue          32549      3      7    5.0
# 3     BMW  Black          11179      5     22    4.0
# 4  Nissan  White         213095      4     35    5.0
# 5  Toyota  Green          99213      4     45    NaN
# 6   Honda   Blue          45698      4     75    NaN
# 7   Honda   Blue          54738      4      7    NaN
# 8  Toyota  White          60000      4    625    NaN
# 9  Nissan  White          31600      4     97    NaN

# %%
car_sales['Seats'].fillna(5,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4      4    5.0
# 1   Honda    Red          87899      4      5    6.0
# 2  Toyota   Blue          32549      3      7    5.0
# 3     BMW  Black          11179      5     22    4.0
# 4  Nissan  White         213095      4     35    5.0
# 5  Toyota  Green          99213      4     45    5.0
# 6   Honda   Blue          45698      4     75    5.0
# 7   Honda   Blue          54738      4      7    5.0
# 8  Toyota  White          60000      4    625    5.0
# 9  Nissan  White          31600      4     97    5.0

# %%
fuel_column=[6,7, 9.7, 8,4, 3,6,6,5.6,7.2]
car_sales["Fuel per 100km"]=fuel_column

# %%
car_sales['Total fuel L']=car_sales['Odometer (KM)']*car_sales['Fuel per 100km']
car_sales['Number of wheels']=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4      4    5.0             6.0
# 1   Honda    Red          87899      4      5    6.0             7.0
# 2  Toyota   Blue          32549      3      7    5.0             9.7
# 3     BMW  Black          11179      5     22    4.0             8.0
# 4  Nissan  White         213095      4     35    5.0             4.0
# 5  Toyota  Green          99213      4     45    5.0             3.0
# 6   Honda   Blue          45698      4     75    5.0             6.0
# 7   Honda   Blue          54738      4      7    5.0             6.0
# 8  Toyota  White          60000      4    625    5.0             5.6
# 9  Nissan  White          31600      4     97    5.0             7.2
#
#    Total fuel L  Number of wheels
# 0      900258.0                 4
# 1      615293.0                 4
# 2      315725.3                 4
# 3       89432.0                 4
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4      4    5.0             6.0
# 1   Honda    Red          87899      4      5    6.0             7.0
# 2  Toyota   Blue          32549      3      7    5.0             9.7
# 3     BMW  Black          11179      5     22    4.0             8.0
# 4  Nissan  White         213095      4     35    5.0             4.0
# 5  Toyota  Green          99213      4     45    5.0             3.0
# 6   Honda   Blue          45698      4     75    5.0             6.0
# 7   Honda   Blue          54738      4      7    5.0             6.0
# 8  Toyota  White          60000      4    625    5.0             5.6
# 9  Nissan  White          31600      4     97    5.0             7.2
#
#    Total fuel L  Number of wheels
# 0      900258.0                 4
# 1      615293.0                 4
# 2      315725.3                 4
# 3       89432.0                 4
# ...

# %%
car_sales_shuffled=car_sales.sample(frac=1)#frace=how many percent of the data we want to take and shuffle 1 is 100%

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 4  Nissan  White         213095      4     35    5.0             4.0
# 0  Toyota  White         150043      4      4    5.0             6.0
# 8  Toyota  White          60000      4    625    5.0             5.6
# 5  Toyota  Green          99213      4     45    5.0             3.0
# 7   Honda   Blue          54738      4      7    5.0             6.0
# 2  Toyota   Blue          32549      3      7    5.0             9.7
# 3     BMW  Black          11179      5     22    4.0             8.0
# 9  Nissan  White          31600      4     97    5.0             7.2
# 1   Honda    Red          87899      4      5    6.0             7.0
# 6   Honda   Blue          45698      4     75    5.0             6.0
#
#    Total fuel L  Number of wheels
# 4      852380.0                 4
# 0      900258.0                 4
# 8      336000.0                 4
# 5      297639.0                 4
# ...

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Nissan  White         213095      4     35    5.0             4.0
# 1  Toyota  White         150043      4      4    5.0             6.0
# 2  Toyota  White          60000      4    625    5.0             5.6
# 3  Toyota  Green          99213      4     45    5.0             3.0
# 4   Honda   Blue          54738      4      7    5.0             6.0
# 5  Toyota   Blue          32549      3      7    5.0             9.7
# 6     BMW  Black          11179      5     22    4.0             8.0
# 7  Nissan  White          31600      4     97    5.0             7.2
# 8   Honda    Red          87899      4      5    6.0             7.0
# 9   Honda   Blue          45698      4     75    5.0             6.0
#
#    Total fuel L  Number of wheels
# 0      852380.0                 4
# 1      900258.0                 4
# 2      336000.0                 4
# 3      297639.0                 4
# ...

# %%
car_sales['Passed safety']=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4      4    5.0             6.0
# 1   Honda    Red          87899      4      5    6.0             7.0
# 2  Toyota   Blue          32549      3      7    5.0             9.7
# 3     BMW  Black          11179      5     22    4.0             8.0
# 4  Nissan  White         213095      4     35    5.0             4.0
# 5  Toyota  Green          99213      4     45    5.0             3.0
# 6   Honda   Blue          45698      4     75    5.0             6.0
# 7   Honda   Blue          54738      4      7    5.0             6.0
# 8  Toyota  White          60000      4    625    5.0             5.6
# 9  Nissan  White          31600      4     97    5.0             7.2
#
#    Total fuel L  Number of wheels  Passed safety
# 0      900258.0                 4           True
# 1      615293.0                 4           True
# 2      315725.3                 4           True
# ...

# %%
#to divide the KM to 1.6 and get mile we use the apply command with the lambda which is a way 
#to assign unknown function a vlue
car_sales['Odometer (KM)']=car_sales['Odometer (KM)'].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Toyota  White      93776.875      4      4    5.0             6.0
# 1   Honda    Red      54936.875      4      5    6.0             7.0
# 2  Toyota   Blue      20343.125      3      7    5.0             9.7
# 3     BMW  Black       6986.875      5     22    4.0             8.0
# 4  Nissan  White     133184.375      4     35    5.0             4.0
# 5  Toyota  Green      62008.125      4     45    5.0             3.0
# 6   Honda   Blue      28561.250      4     75    5.0             6.0
# 7   Honda   Blue      34211.250      4      7    5.0             6.0
# 8  Toyota  White      37500.000      4    625    5.0             5.6
# 9  Nissan  White      19750.000      4     97    5.0             7.2
#
#    Total fuel L  Number of wheels  Passed safety
# 0      900258.0                 4           True
# 1      615293.0                 4           True
# 2      315725.3                 4           True
# ...

# %%
car_sales['Number of glasses']=8
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Toyota  White      93776.875      4      4    5.0             6.0
# 1   Honda    Red      54936.875      4      5    6.0             7.0
# 2  Toyota   Blue      20343.125      3      7    5.0             9.7
# 3     BMW  Black       6986.875      5     22    4.0             8.0
# 4  Nissan  White     133184.375      4     35    5.0             4.0
# 5  Toyota  Green      62008.125      4     45    5.0             3.0
# 6   Honda   Blue      28561.250      4     75    5.0             6.0
# 7   Honda   Blue      34211.250      4      7    5.0             6.0
# 8  Toyota  White      37500.000      4    625    5.0             5.6
# 9  Nissan  White      19750.000      4     97    5.0             7.2
#
#    Total fuel L  Number of wheels  Passed safety  Number of glasses
# 0      900258.0                 4           True                  8
# 1      615293.0                 4           True                  8
# ...

# %%
car_sales.drop('Number of glasses',axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100km  \
# 0  Toyota  White      93776.875      4      4    5.0             6.0
# 1   Honda    Red      54936.875      4      5    6.0             7.0
# 2  Toyota   Blue      20343.125      3      7    5.0             9.7
# 3     BMW  Black       6986.875      5     22    4.0             8.0
# 4  Nissan  White     133184.375      4     35    5.0             4.0
# 5  Toyota  Green      62008.125      4     45    5.0             3.0
# 6   Honda   Blue      28561.250      4     75    5.0             6.0
# 7   Honda   Blue      34211.250      4      7    5.0             6.0
# 8  Toyota  White      37500.000      4    625    5.0             5.6
# 9  Nissan  White      19750.000      4     97    5.0             7.2
#
#    Total fuel L  Number of wheels  Passed safety
# 0      900258.0                 4           True
# 1      615293.0                 4           True
# 2      315725.3                 4           True
# ...
